# %% [markdown]
# ![heart.jpg](attachment:heart.jpg)
#
# **A MACHINE LEARNING APPROACH TO HEART DISEASE PREDICTION**
# ---

# %% [markdown]
# Importing essential libraries needed for this project

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams['figure.figsize']= (15, 15)

# %% [markdown]
# Let's view the data

# %%
df = pd.read_csv('heartdisease.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  Target
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
print(df.shape)
df.describe()
# Out:
# (303, 14)
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# **DATA CLEANING AND PREPROCESSING**
# --

# %% [markdown]
# It's important we check for null and duplicates values in other to get our expected result

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# Target      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(keep=False, inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  Target
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**
# ---

# %% [markdown]
# Let's visualize our data

# %%
sns.set_style('whitegrid')
sns.pairplot(df)
plt.show()

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'cp'}>,
#         <AxesSubplot:title={'center':'trtbps'}>],
#        [<AxesSubplot:title={'center':'chol'}>,
#         <AxesSubplot:title={'center':'fbs'}>,
#         <AxesSubplot:title={'center':'restecg'}>,
#         <AxesSubplot:title={'center':'thalachh'}>],
#        [<AxesSubplot:title={'center':'exng'}>,
#         <AxesSubplot:title={'center':'oldpeak'}>,
#         <AxesSubplot:title={'center':'slp'}>,
#         <AxesSubplot:title={'center':'caa'}>],
#        [<AxesSubplot:title={'center':'thall'}>,
#         <AxesSubplot:title={'center':'Target'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.plot(kind='box')
plt.show()

# %%
(df['chol']>350).value_counts()
# Out:
# False    293
# True       8
# Name: chol, dtype: int64

# %%
p=df.corr()
sns.heatmap(p, vmin=-1,vmax=1, cmap = "Reds", annot=True, linewidth=0.1)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Target', data=df)
# Out:
# <AxesSubplot:xlabel='Target', ylabel='count'>

# %%
cate_columns=['age','oldpeak','trtbps','chol','thalachh']

# %%
sns.pairplot(df[cate_columns])

# %%
sns.distplot(df['age'])
plt.show()

# %%
sns.distplot(df['trtbps'])
plt.show()

# %%
sns.distplot(df['chol'])
plt.show()

# %%
sns.distplot(df['thalachh'])
plt.show()

# %%
sns.distplot(df['oldpeak'])
plt.show()

# %% [markdown]
# **PARTIONING**
# ---

# %%
Y = df.Target
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: Target, Length: 301, dtype: int64

# %%
X =df.drop(labels="Target", axis=1)
X
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall
# 0      0      1
# 1      0      2
# ...
